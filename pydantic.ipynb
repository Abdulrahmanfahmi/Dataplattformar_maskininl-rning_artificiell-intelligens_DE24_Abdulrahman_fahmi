# %% [markdown]
# # Pyndatic fundamentals

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        self.name = name
        self.gender = gender 
        self.age = age        


person1 = Person(name="abdulrahman", age=24, gender="Male")  # Person med stor P

print(person1)
print(f"Namn: {person1.name}")
print(f"Ålder: {person1.age}")
print(f"Kön: {person1.gender}")
# Out:
# ...
# Namn: abdulrahman
# Ålder: 24
# Kön: Male

# %%
person2 = Person(name = 3213+3213, gender = True, age="minus ten")
person2

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        self.name = name
        self.gender = gender 
        self.age = age        


person1 = Person(name="abdulrahman", age=24, gender="Male")  
person1

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        if not isinstance(name, str):
            raise TypeError (f"name must be of type str not {type(name)}")
        self.name = name
        self.gender = gender 
        self.age = age        

try:
    person1 = Person(name= 3.1415, age=24, gender="Male")  
except TypeError as err:
    print(err)
# Out:
# name must be of type str not <class 'float'>

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        if not isinstance(name, str):
            raise TypeError (f"name must be of type str not {type(name)}")
        self.name = name
        self.gender = gender 
        self.age = age        
    def __repr__(self):
        return f"Person({self.name}, {self.gender}, {self.age})"

try:
    person3 = Person(name= "jaffar", age=34, gender="Male")  
except TypeError as err:
    print(err)

person3
# Out:
# Person(jaffar, Male, 34)

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        if not isinstance(name, str):
            raise TypeError (f"name must be of type str not {type(name)}")
        self.name = name
        self.gender = gender 
        if not isinstance(age,int):
            raise TypeError(f"age must be of type int not {type(age)}")
        if not 0 <= age < 125:
            raise ValueError(f"age must be between 0 and 124 not {age}")
        self.age = age    


    def __repr__(self):
        return f"Person({self.name}, {self.gender}, {self.age})"

try:
    person3 = Person(name= "jaffar", age=-100, gender="Male")  
except ValueError as err:
    print(err)

person3
# Out:
# age must be between 0 and 124 not -100
# Person(jaffar, Male, 34)

# %%
class Person:
    def __init__(self, name: str, gender: str, age: int) -> None:
        if not isinstance(name, str):
            raise TypeError (f"name must be of type str not {type(name)}")
        self.name = name
        self.gender = gender 
        self.age = age

    @property
    def age(self):
        return self._age

    @age.setter
    def age(self, age):
        if not isinstance(age,int):
            raise TypeError(f"age must be of type int not {type(age)}")
        if not 0 <= age < 125:
            raise ValueError(f"age must be between 0 and 124 not {age}")
        self._age = age    


    def __repr__(self):
        return f"Person({self.name}, {self.gender}, {self.age})"

person5 = Person(name= "wael", age=10, gender="Male")  
person5
# Out:
# Person(wael, Male, 10)

# %%
try:
    person5.age = 124
except ValueError as err:
    print(er)

# %%
try:
    Person(name= "wael", age=10, gender="Male")  
except TypeError as err:
    print(er)

# %% [markdown]
# # Validate using pydantic

# %%
from pydantic import BaseModel

class person(BaseModel):
    name:str 
    gender: str
    age: int

person6 = Person(name = "zahra", gender = "female", age = 24)
person6
# Out:
# Person(zahra, female, 24)

# %%
person6.age = 46
person6
# Out:
# Person(zahra, female, 46)

# %%
from pydantic import ValidationError

try:
    Person(name = "zahra", gender = "female", age = 24)
except ValidationError as err:
    print(err)

# %%
from pydantic import ConfigDict

class Person(BaseModel):
    name:str 
    gender: str
    age: int

    model_config = ConfigDict(validate_assignment=True)

Person7 = Person(name = "", gender = "female", age = 24)
try: 
    Person7.age = "thirty"
except ValidationError as err:
    print(err)

person7.age = 10
person7
# Out:
# 1 validation error for Person
# age
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='thirty', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_parsing
# Person(, female, 10)

# %%
try: 
    Person(name = 3.1415, gender=2.714, age = -4)
except ValidationError as err:
    print(err)
# Out:
# 2 validation errors for Person
# name
#   Input should be a valid string [type=string_type, input_value=3.1415, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# gender
#   Input should be a valid string [type=string_type, input_value=2.714, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %% [markdown]
# # Add age validation

# %%
from pydantic import Field

class Person(BaseModel):
    name:str 
    gender: str
    age: int = Field(gt = -1, lt = 125)

    model_config = ConfigDict(validate_assignment=True)

try: 
    Person(name = "ibrahim", gender="male", age = 4)
except ValidationError as err:
    print(err)

# %%
from pydantic import Field
from typing import Literal

class Person(BaseModel):
    name:str 
    gender: Literal["M", "F"]
    age: int = Field(gt = -1, lt = 125)

    model_config = ConfigDict(validate_assignment=True)

try: 
    Person(name = "ibrahim", gender="male", age = 4)
except ValidationError as err:
    print(err)
# Out:
# 1 validation error for Person
# gender
#   Input should be 'M' or 'F' [type=literal_error, input_value='male', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/literal_error

# %% [markdown]
# # Serialization and deserialization

# %%
Person7.model_dump()
# Out:
# {'name': '', 'gender': 'female', 'age': 24}

# %%
import json
with open("Person.json", "w") as file:
    json.dump(Person7.model_dump(), file)

# %%
with open("Person.json", "r") as file:
    json_data = file.read()

print(json_data)
# Out:
# {"name": "", "gender": "female", "age": 24}

# %%
with open("Person.json", "r") as file:
    json_date = file.read()

print(repr(json_data))
# Out:
# '{"name": "", "gender": "female", "age": 24}'

# %%
with open("Person.json", "r") as file:
    json_data = file.read()

print(repr(json_data))


Person.model_validate_json(json_data)
# Out:
# '{"name": "", "gender": "F", "age": 24}'
# Person(name='', gender='F', age=24)
