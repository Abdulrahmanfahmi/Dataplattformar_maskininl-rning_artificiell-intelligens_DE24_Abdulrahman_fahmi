# %% [markdown]
# # structure gemini outputs with pydantic

# %%
from google import genai 
import pydantic


client = genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients"

)

print(response.text)
# Out:
# Here are a few iconic Asian soup recipes with yummy descriptions and their key ingredients!
#
# ---
#
# ### 1. Tom Yum Goong (Thai Spicy Shrimp Soup)
#
# **Yummy Description:** A vibrant explosion of Thai flavors, Tom Yum Goong is a true culinary masterpiece. This iconic hot and sour soup awakens your senses with a fragrant symphony of lemongrass, galangal, kaffir lime leaves, and fiery bird's eye chilies. Plump, juicy shrimp swim in a clear, zesty broth, creating an exhilarating and unforgettable taste experience that's both refreshing and deeply satisfying. It's a sunshine in a bowl!
#
# **Key Ingredients:**
# *   **Shrimp:** Fresh, peeled, and deveined.
# *   **Broth:** Chicken or vegetable broth (or just water).
# *   **Aromatics:** Fresh lemongrass (bruised), galangal (sliced), kaffir lime leaves (torn).
# *   **Spice:** Bird's eye chilies (fresh, crushed or sliced).
# *   **Flavoring:** Fish sauce, fresh lime juice.
# *   **Vegetables/Mushrooms:** Straw mushrooms or oyster mushrooms, cherry tomatoes (halved).
# *   **Garnish:** Fresh cilantro leaves.
# *   **Optional:** Tom Yum paste or chili paste (nam prik pao) for extra depth and color.
#
# ---
#
# ### 2. Pho Bo (Vietnamese Beef Noodle Soup)
#
# **Yummy Description:** The ultimate Vietnamese comfort food, Pho Bo is a deeply aromatic and profoundly satisfying beef noodle soup. Its clear, golden broth is simmered for hours with warming spices like star anise, cardamom, cinnamon, and cloves, imparting an intoxicating fragrance. Slippery rice noodles, thinly sliced tender beef (often partially cooked by the hot broth), and a vibrant medley of fresh herbs (basil, cilantro, mint) create a harmonious dance of textures and tastes. It's a soul-hugging bowl that promises warmth and culinary bliss.
#
# **Key Ingredients:**
# *   **Broth Base:** Beef bones (marrow, knuckle, oxtail), water.
# *   **Spices (for broth):** Star anise, black cardamom pods, cinnamon sticks, cloves, coriander seeds, fennel seeds (often toasted).
# *   **Aromatics (for broth):** Ginger (charred), yellow onion (charred).
# *   **Sweetener/Seasoning:** Rock sugar, fish sauce.
# *   **Beef:** Thinly sliced raw beef (e.g., eye of round, flank steak), sometimes also cooked brisket or meatballs.
# *   **Noodles:** Flat rice noodles (banh pho).
# *   **Accompaniments/Garnish:** Bean sprouts, fresh Thai basil, cilantro, lime wedges, sliced jalapeños or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 3. Shoyu Ramen (Japanese Soy Sauce Ramen)
#
# **Yummy Description:** A soul-warming bowl of Japanese culinary artistry, Shoyu Ramen boasts an incredibly flavorful, umami-rich broth seasoned with savory soy sauce, offering depth and complexity that’s both comforting and invigorating. It’s perfectly paired with bouncy, chewy ramen noodles, melt-in-your-mouth tender chashu pork, a perfectly jammy marinated ajitama (soft-boiled egg), crisp nori (seaweed), and fresh scallions. Each slurp is a journey of textures and tastes, a truly satisfying experience from the first spoonful to the last.
#
# **Key Ingredients:**
# *   **Broth:** Chicken, pork, or dashi (kelp and bonito) based broth.
# *   **Tare (Flavoring Concentrate):** Japanese soy sauce (shoyu), mirin, sake, dashi or broth.
# *   **Ramen Noodles:** Fresh or dried ramen noodles (thin, wavy, or thick).
# *   **Toppings:**
#     *   **Chashu:** Braised pork belly or shoulder (thinly sliced).
#     *   **Ajitama:** Marinated soft-boiled egg.
#     *   **Nori:** Dried seaweed sheets.
#     *   **Scallions:** Green onions (sliced).
#     *   **Optional:** Bamboo shoots (menma), fish cake (narutomaki), spinach, sesame seeds.
# *   **Aromatics:** Garlic, ginger (often in the tare or broth).
# *   **Fat:** A drizzle of aromatic oil (e.g., chicken fat, lard, or sesame oil).
#
# ---
#
# ### 4. Hot and Sour Soup (Sichuan Style)
#
# **Yummy Description:** An exhilarating dance of flavors, Chinese Hot and Sour Soup is a classic for a reason! Its piquant, tangy, and subtly spicy broth, thickened to a silky consistency, offers a delightful kick of white pepper and vinegar that awakens the palate. Loaded with thinly sliced wood ear mushrooms, bamboo shoots, delicate silken tofu, and often shredded pork, it's a warming and incredibly satisfying bowl that balances its intense flavors with a comforting, savory depth. Each spoonful is an adventure!
#
# **Key Ingredients:**
# *   **Broth:** Chicken or vegetable broth.
# *   **Flavoring:** Rice vinegar, soy sauce, white pepper, sesame oil, chili oil (optional).
# *   **Thickener:** Cornstarch slurry.
# *   **Protein/Fillers:** Shredded pork or chicken (optional), silken or firm tofu (julienned), rehydrated dried wood ear mushrooms (julienned), bamboo shoots (julienned).
# *   **Egg:** Whisked egg, drizzled into the hot soup to create delicate ribbons.
# *   **Garnish:** Green onions (sliced).
# *   **Optional:** Dried shiitake mushrooms, red chili flakes.

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients give me fields of recipe_name:str description: str ingredients: list[str] not in markdown format"""

)

response.text
# Out:
# 'recipe_name: Vietnamese Pho Bo (Beef Noodle Soup) description: A fragrant and deeply comforting Vietnamese staple, featuring a slow-simmered, aromatic beef broth infused with star anise, cinnamon, and ginger, poured over delicate rice noodles, tender slices of beef, and garnished with a vibrant array of fresh herbs, lime, and chili. It\'s a symphony of savory, sweet, and herbaceous flavors that warm you from the inside out. ingredients: ["Beef bones (marrow and knuckle)", "Beef brisket or chuck", "Star anise", "Cinnamon sticks", "Black cardamom pods", "Cloves", "Fennel seeds", "Ginger", "Onions", "Fish sauce", "Rock sugar", "Rice noodles (banh pho)", "Thinly sliced raw beef (sirloin, eye round)", "Bean sprouts", "Thai basil", "Cilantro", "Scallions", "Lime wedges", "Jalapeño or Serrano chilies", "Hoisin sauce", "Sriracha"]\nrecipe_name: Japanese Tonkotsu Ramen description: Indulge in the creamy, milky richness of Tonkotsu Ramen, a soul-satisfying Japanese masterpiece. Its opaque, collagen-rich pork bone broth, simmered for hours until incredibly flavorful, perfectly coats springy ramen noodles. Each bowl is a canvas for delicious toppings like tender chashu pork belly, a perfectly jammy ajitama egg, crisp scallions, and savory nori, creating an utterly decadent and unforgettable experience. ingredients: ["Pork femurs and trotters", "Water", "Garlic", "Ginger", "Onions", "Scallions", "Ramen noodles", "Chashu pork belly", "Ajitama (marinated soft-boiled egg)", "Nori (seaweed sheets)", "Wood ear mushrooms", "Bamboo shoots (menma)", "Sesame seeds", "Rayu (chili oil)", "Soy sauce (for tare)", "Sake (for tare)", "Mirin (for tare)"]\nrecipe_name: Thai Tom Yum Goong (Spicy Shrimp Soup) description: Brace yourself for an explosion of vibrant Thai flavors with Tom Yum Goong, a zesty and aromatic hot and sour shrimp soup. This iconic dish perfectly balances spicy bird\'s eye chilies with tart lime juice, fragrant lemongrass, galangal, and kaffir lime leaves, all swimming alongside succulent shrimp and mushrooms. Each spoonful is a thrilling dance of sweet, sour, salty, and spicy notes, invigorating your senses. ingredients: ["Shrimp (peeled and deveined)", "Lemongrass stalks", "Galangal (or ginger)", "Kaffir lime leaves", "Bird\'s eye chilies", "Fish sauce", "Lime juice", "Mushrooms (straw or oyster)", "Cherry tomatoes", "Cilantro", "Spring onions", "Chili paste (Nam Prik Pao - optional)", "Chicken or vegetable broth"]\nrecipe_name: Korean Kimchi Jjigae (Kimchi Stew) description: A hearty and deeply satisfying Korean comfort food, Kimchi Jjigae is a fiery and flavorful stew starring aged, fermented kimchi. Simmered to perfection with tender slices of pork belly (or tofu), robust gochujang, and a medley of savory vegetables, this bubbling hot pot offers a delightful blend of spicy, sour, and umami tastes. It\'s the ultimate warming dish, perfect for a cozy meal with a bowl of rice. ingredients: ["Aged kimchi", "Pork belly or shoulder (or firm tofu)", "Onions", "Garlic", "Green onions", "Gochujang (Korean chili paste)", "Gochugaru (Korean chili powder)", "Doenjang (Korean soybean paste - optional)", "Sesame oil", "Soy sauce", "Sugar", "Tofu (firm or soft)", "Mushrooms (enoki or oyster)", "Water or anchovy broth", "Rice cakes (optional)"]\nrecipe_name: Chinese Hot and Sour Soup (Suan La Tang) description: Awaken your palate with the tantalizing tang and gentle heat of Chinese Hot and Sour Soup. This classic features a savory, brothy base thickened to perfection, brimming with slivers of tender pork, shiitake mushrooms, bamboo shoots, and silken tofu. A masterful balance of black vinegar and white pepper provides its signature \'sour\' and \'hot\' kick, creating a wonderfully complex and utterly addictive flavor profile. ingredients: ["Pork loin or chicken breast (shredded)", "Dried shiitake mushrooms", "Bamboo shoots (shredded)", "Firm tofu (shredded)", "Dried wood ear fungus (optional)", "Chicken or vegetable broth", "Rice vinegar (black  ...

# %%
response.text
# Out:
# 'recipe_name: Vietnamese Pho Bo (Beef Noodle Soup) description: A fragrant and deeply comforting Vietnamese staple, featuring a slow-simmered, aromatic beef broth infused with star anise, cinnamon, and ginger, poured over delicate rice noodles, tender slices of beef, and garnished with a vibrant array of fresh herbs, lime, and chili. It\'s a symphony of savory, sweet, and herbaceous flavors that warm you from the inside out. ingredients: ["Beef bones (marrow and knuckle)", "Beef brisket or chuck", "Star anise", "Cinnamon sticks", "Black cardamom pods", "Cloves", "Fennel seeds", "Ginger", "Onions", "Fish sauce", "Rock sugar", "Rice noodles (banh pho)", "Thinly sliced raw beef (sirloin, eye round)", "Bean sprouts", "Thai basil", "Cilantro", "Scallions", "Lime wedges", "Jalapeño or Serrano chilies", "Hoisin sauce", "Sriracha"]\nrecipe_name: Japanese Tonkotsu Ramen description: Indulge in the creamy, milky richness of Tonkotsu Ramen, a soul-satisfying Japanese masterpiece. Its opaque, collagen-rich pork bone broth, simmered for hours until incredibly flavorful, perfectly coats springy ramen noodles. Each bowl is a canvas for delicious toppings like tender chashu pork belly, a perfectly jammy ajitama egg, crisp scallions, and savory nori, creating an utterly decadent and unforgettable experience. ingredients: ["Pork femurs and trotters", "Water", "Garlic", "Ginger", "Onions", "Scallions", "Ramen noodles", "Chashu pork belly", "Ajitama (marinated soft-boiled egg)", "Nori (seaweed sheets)", "Wood ear mushrooms", "Bamboo shoots (menma)", "Sesame seeds", "Rayu (chili oil)", "Soy sauce (for tare)", "Sake (for tare)", "Mirin (for tare)"]\nrecipe_name: Thai Tom Yum Goong (Spicy Shrimp Soup) description: Brace yourself for an explosion of vibrant Thai flavors with Tom Yum Goong, a zesty and aromatic hot and sour shrimp soup. This iconic dish perfectly balances spicy bird\'s eye chilies with tart lime juice, fragrant lemongrass, galangal, and kaffir lime leaves, all swimming alongside succulent shrimp and mushrooms. Each spoonful is a thrilling dance of sweet, sour, salty, and spicy notes, invigorating your senses. ingredients: ["Shrimp (peeled and deveined)", "Lemongrass stalks", "Galangal (or ginger)", "Kaffir lime leaves", "Bird\'s eye chilies", "Fish sauce", "Lime juice", "Mushrooms (straw or oyster)", "Cherry tomatoes", "Cilantro", "Spring onions", "Chili paste (Nam Prik Pao - optional)", "Chicken or vegetable broth"]\nrecipe_name: Korean Kimchi Jjigae (Kimchi Stew) description: A hearty and deeply satisfying Korean comfort food, Kimchi Jjigae is a fiery and flavorful stew starring aged, fermented kimchi. Simmered to perfection with tender slices of pork belly (or tofu), robust gochujang, and a medley of savory vegetables, this bubbling hot pot offers a delightful blend of spicy, sour, and umami tastes. It\'s the ultimate warming dish, perfect for a cozy meal with a bowl of rice. ingredients: ["Aged kimchi", "Pork belly or shoulder (or firm tofu)", "Onions", "Garlic", "Green onions", "Gochujang (Korean chili paste)", "Gochugaru (Korean chili powder)", "Doenjang (Korean soybean paste - optional)", "Sesame oil", "Soy sauce", "Sugar", "Tofu (firm or soft)", "Mushrooms (enoki or oyster)", "Water or anchovy broth", "Rice cakes (optional)"]\nrecipe_name: Chinese Hot and Sour Soup (Suan La Tang) description: Awaken your palate with the tantalizing tang and gentle heat of Chinese Hot and Sour Soup. This classic features a savory, brothy base thickened to perfection, brimming with slivers of tender pork, shiitake mushrooms, bamboo shoots, and silken tofu. A masterful balance of black vinegar and white pepper provides its signature \'sour\' and \'hot\' kick, creating a wonderfully complex and utterly addictive flavor profile. ingredients: ["Pork loin or chicken breast (shredded)", "Dried shiitake mushrooms", "Bamboo shoots (shredded)", "Firm tofu (shredded)", "Dried wood ear fungus (optional)", "Chicken or vegetable broth", "Rice vinegar (black  ...

# %%
print(response.text)
# Out:
# recipe_name: Vietnamese Pho Bo (Beef Noodle Soup) description: A fragrant and deeply comforting Vietnamese staple, featuring a slow-simmered, aromatic beef broth infused with star anise, cinnamon, and ginger, poured over delicate rice noodles, tender slices of beef, and garnished with a vibrant array of fresh herbs, lime, and chili. It's a symphony of savory, sweet, and herbaceous flavors that warm you from the inside out. ingredients: ["Beef bones (marrow and knuckle)", "Beef brisket or chuck", "Star anise", "Cinnamon sticks", "Black cardamom pods", "Cloves", "Fennel seeds", "Ginger", "Onions", "Fish sauce", "Rock sugar", "Rice noodles (banh pho)", "Thinly sliced raw beef (sirloin, eye round)", "Bean sprouts", "Thai basil", "Cilantro", "Scallions", "Lime wedges", "Jalapeño or Serrano chilies", "Hoisin sauce", "Sriracha"]
# recipe_name: Japanese Tonkotsu Ramen description: Indulge in the creamy, milky richness of Tonkotsu Ramen, a soul-satisfying Japanese masterpiece. Its opaque, collagen-rich pork bone broth, simmered for hours until incredibly flavorful, perfectly coats springy ramen noodles. Each bowl is a canvas for delicious toppings like tender chashu pork belly, a perfectly jammy ajitama egg, crisp scallions, and savory nori, creating an utterly decadent and unforgettable experience. ingredients: ["Pork femurs and trotters", "Water", "Garlic", "Ginger", "Onions", "Scallions", "Ramen noodles", "Chashu pork belly", "Ajitama (marinated soft-boiled egg)", "Nori (seaweed sheets)", "Wood ear mushrooms", "Bamboo shoots (menma)", "Sesame seeds", "Rayu (chili oil)", "Soy sauce (for tare)", "Sake (for tare)", "Mirin (for tare)"]
# recipe_name: Thai Tom Yum Goong (Spicy Shrimp Soup) description: Brace yourself for an explosion of vibrant Thai flavors with Tom Yum Goong, a zesty and aromatic hot and sour shrimp soup. This iconic dish perfectly balances spicy bird's eye chilies with tart lime juice, fragrant lemongrass, galangal, and kaffir lime leaves, all swimming alongside succulent shrimp and mushrooms. Each spoonful is a thrilling dance of sweet, sour, salty, and spicy notes, invigorating your senses. ingredients: ["Shrimp (peeled and deveined)", "Lemongrass stalks", "Galangal (or ginger)", "Kaffir lime leaves", "Bird's eye chilies", "Fish sauce", "Lime juice", "Mushrooms (straw or oyster)", "Cherry tomatoes", "Cilantro", "Spring onions", "Chili paste (Nam Prik Pao - optional)", "Chicken or vegetable broth"]
# recipe_name: Korean Kimchi Jjigae (Kimchi Stew) description: A hearty and deeply satisfying Korean comfort food, Kimchi Jjigae is a fiery and flavorful stew starring aged, fermented kimchi. Simmered to perfection with tender slices of pork belly (or tofu), robust gochujang, and a medley of savory vegetables, this bubbling hot pot offers a delightful blend of spicy, sour, and umami tastes. It's the ultimate warming dish, perfect for a cozy meal with a bowl of rice. ingredients: ["Aged kimchi", "Pork belly or shoulder (or firm tofu)", "Onions", "Garlic", "Green onions", "Gochujang (Korean chili paste)", "Gochugaru (Korean chili powder)", "Doenjang (Korean soybean paste - optional)", "Sesame oil", "Soy sauce", "Sugar", "Tofu (firm or soft)", "Mushrooms (enoki or oyster)", "Water or anchovy broth", "Rice cakes (optional)"]
# recipe_name: Chinese Hot and Sour Soup (Suan La Tang) description: Awaken your palate with the tantalizing tang and gentle heat of Chinese Hot and Sour Soup. This classic features a savory, brothy base thickened to perfection, brimming with slivers of tender pork, shiitake mushrooms, bamboo shoots, and silken tofu. A masterful balance of black vinegar and white pepper provides its signature 'sour' and 'hot' kick, creating a wonderfully complex and utterly addictive flavor profile. ingredients: ["Pork loin or chicken breast (shredded)", "Dried shiitake mushrooms", "Bamboo shoots (shredded)", "Firm tofu (shredded)", "Dried wood ear fungus (optional)", "Chicken or vegetable broth", "Rice vinegar (black vinegar preferred)", "White pepper", "Soy sauce", "Sesame oil", "Cornstarch (for thickening)", "Eggs (beaten)", "Scallions (for garnish)", "Chili oil (optional, for extra heat)"]

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str 
    description: str
    ingredients: list[str]

client = genai.Client()


response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config= {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [
#   {
#     "recipe_name": "Traditional Miso Soup",
#     "description": "A comforting and savory Japanese soup, light yet full of umami. Made with dashi broth and miso paste, often containing silken tofu and wakame seaweed.",
#     "ingredients": [
#       "dashi stock",
#       "miso paste",
#       "silken tofu",
#       "wakame seaweed",
#       "green onions"
#     ]
#   },
#   {
#     "recipe_name": "Spicy Tom Yum Goong",
#     "description": "A vibrant and aromatic Thai hot and sour soup featuring succulent shrimp, infused with lemongrass, galangal, kaffir lime leaves, and a kick of chili.",
#     "ingredients": [
#       "shrimp",
#       "lemongrass",
#       "galangal",
#       "kaffir lime leaves",
#       "mushrooms",
#       "fish sauce",
#       "lime juice",
#       "chili paste",
#       "cherry tomatoes",
#       "cilantro"
#     ]
#   },
#   {
#     "recipe_name": "Classic Vietnamese Pho Bo (Beef Noodle Soup)",
#     "description": "A fragrant and deeply flavorful Vietnamese beef noodle soup, renowned for its clear, aromatic broth, tender slices of beef, and chewy rice noodles, garnished with fresh herbs.",
#     "ingredients": [
#       "beef bones",
#       "beef brisket",
#       "rice noodles",
#       "ginger",
#       "onions",
#       "star anise",
#       "cinnamon stick",
#       "cardamom pods",
#       "fish sauce",
#       "bean sprouts",
#       "basil",
#       "lime",
#       "jalapeños"
#     ]
#   }
# ]

# %%
response.parsed
# Out:
# [Recipe(recipe_name='Traditional Miso Soup', description='A comforting and savory Japanese soup, light yet full of umami. Made with dashi broth and miso paste, often containing silken tofu and wakame seaweed.', ingredients=['dashi stock', 'miso paste', 'silken tofu', 'wakame seaweed', 'green onions']),
#  Recipe(recipe_name='Spicy Tom Yum Goong', description='A vibrant and aromatic Thai hot and sour soup featuring succulent shrimp, infused with lemongrass, galangal, kaffir lime leaves, and a kick of chili.', ingredients=['shrimp', 'lemongrass', 'galangal', 'kaffir lime leaves', 'mushrooms', 'fish sauce', 'lime juice', 'chili paste', 'cherry tomatoes', 'cilantro']),
#  Recipe(recipe_name='Classic Vietnamese Pho Bo (Beef Noodle Soup)', description='A fragrant and deeply flavorful Vietnamese beef noodle soup, renowned for its clear, aromatic broth, tender slices of beef, and chewy rice noodles, garnished with fresh herbs.', ingredients=['beef bones', 'beef brisket', 'rice noodles', 'ginger', 'onions', 'star anise', 'cinnamon stick', 'cardamom pods', 'fish sauce', 'bean sprouts', 'basil', 'lime', 'jalapeños'])]

# %%
recipes = response.parsed
len(recipes)
# Out:
# 3

# %%
recipes[0].description
# Out:
# 'A comforting and savory Japanese soup, light yet full of umami. Made with dashi broth and miso paste, often containing silken tofu and wakame seaweed.'

# %%
recipes[0].recipe_name
# Out:
# 'Traditional Miso Soup'

# %%
recipes[0].ingredients
# Out:
# ['dashi stock', 'miso paste', 'silken tofu', 'wakame seaweed', 'green onions']

# %% [markdown]
# # Simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_rooms: int 
    type: Literal["apartment", "house"]
    address: str


response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = """List 50 apartment and houses in sweden with their monthly fee, price, living area, number of rooms, address, type if it is apartment or house. All currencies are in SEK. Data should be simulation of swedish housing.""",
    config= {"response_mime_type": "application/json", "response_schema": list[Home]}
)

# %%
homes = response.parsed
homes
# Out:
# [Home(price=4200000, monthly_fee=3800, living_area=75.5, number_rooms=3, type='apartment', address='Vasagatan 12A, Stockholm'),
#  Home(price=6800000, monthly_fee=2200, living_area=140.0, number_rooms=5, type='house', address='Ekallén 5, Göteborg'),
#  Home(price=2850000, monthly_fee=4500, living_area=62.0, number_rooms=2, type='apartment', address='Södra Förstadsgatan 33, Malmö'),
#  Home(price=3100000, monthly_fee=1800, living_area=110.0, number_rooms=4, type='house', address='Björkvägen 15, Uppsala'),
#  Home(price=5500000, monthly_fee=5200, living_area=95.0, number_rooms=4, type='apartment', address='Kungsportsavenyen 20, Göteborg'),
#  Home(price=7500000, monthly_fee=3100, living_area=170.0, number_rooms=6, type='house', address='Drottninggatan 88, Stockholm'),
#  Home(price=2100000, monthly_fee=3200, living_area=48.0, number_rooms=2, type='apartment', address='Storgatan 7, Linköping'),
#  Home(price=4300000, monthly_fee=2500, living_area=125.0, number_rooms=5, type='house', address='Solhemsgatan 7, Västerås'),
#  Home(price=3500000, monthly_fee=4800, living_area=70.0, number_rooms=3, type='apartment', address='Järnvägsgatan 10, Helsingborg'),
#  Home(price=9500000, monthly_fee=4100, living_area=210.0, number_rooms=7, type='house', address='Solsätervägen 3, Lidingö'),
#  Home(price=1900000, monthly_fee=2900, living_area=35.0, number_rooms=1, type='apartment', address='Studentvägen 5, Lund'),
#  Home(price=6200000, monthly_fee=2800, living_area=155.0, number_rooms=5, type='house', address='Granvägen 22, Umeå'),
#  Home(price=4800000, monthly_fee=5800, living_area=88.0, number_rooms=3, type='apartment', address='Hamngatan 1, Malmö'),
#  Home(price=3700000, monthly_fee=1500, living_area=100.0, number_rooms=4, type='house', address='Hantverkargatan 18, Örebro'),
#  Home(price=2600000, monthly_fee=4100, living_area=55.0, number_rooms=2, type='apartment', address='Västra Esplanaden 12, Växjö'),
#  Home(price=8800000, monthly_fee=3500, living_area=190.0, number_rooms=6, type='house', address='Stenhagsvägen 7, Nacka'),
#  Home(price=3900000, monthly_fee=5000, living_area=80.0, number_rooms=3, type='apartment', address='Kungsgatan 42, Stockholm'),
#  Home(price=5100000, monthly_fee=2700, living_area=130.0, number_rooms=4, type='house', address='Odengatan 5, Halmstad'),
#  Home(price=1750000, monthly_fee=2800, living_area=30.0, number_rooms=1, type='apartment', address='Trädgårdsgatan 2B, Jönköping'),
#  Home(price=7200000, monthly_fee=3000, living_area=160.0, number_rooms=5, type='house', address='Fågelsångsvägen 11, Karlstad'),
#  Home(price=3300000, monthly_fee=4300, living_area=68.0, number_rooms=2, type='apartment', address='Svartbäcksgatan 1, Uppsala'),
#  Home(price=4900000, monthly_fee=2100, living_area=115.0, number_rooms=4, type='house', address='Kattfotgatan 9, Borås'),
#  Home(price=5900000, monthly_fee=5500, living_area=105.0, number_rooms=4, type='apartment', address='Linnégatan 30, Göteborg'),
#  Home(price=10500000, monthly_fee=3800, living_area=220.0, number_rooms=7, type='house', address='Strandvägen 1A, Djursholm'),
#  Home(price=2400000, monthly_fee=3900, living_area=50.0, number_rooms=2, type='apartment', address='Ågatan 17, Eskilstuna'),
#  Home(price=4600000, monthly_fee=2600, living_area=120.0, number_rooms=4, type='house', address='Blåklintsvägen 14, Gävle'),
#  Home(price=3000000, monthly_fee=4700, living_area=65.0, number_rooms=2, type='apartment', address='Stortorget 5, Örebro'),
#  Home(price=8100000, monthly_fee=3200, living_area=180.0, number_rooms=6, type='house', address='Rådjursstigen 2, Täby'),
#  Home(price=4400000, monthly_fee=5100, living_area=85.0, number_rooms=3, type='apartment', address='Karlavägen 78, Stockholm'),
#  Home(price=5300000, monthly_fee=2300, living_area=135.0, number_rooms=5, type='house', address='Smedjegatan 10, Växjö'),
#  Home(price=2200000, monthly_fee=3400, living_area=40.0, number_rooms=1, type='apartment', address='Klostergatan 21, Skövde'),
#  Home(price=7000000, monthly_fee=2900, living_area=165.0, number_rooms=5, type='house', address='Lokes väg 8, Norrköping'),
#  Home(price=3600000, monthly_fee=4900, living_area=72.0, number_rooms=3, type='apartment', address='Fredriksbergsvägen 15, Kalmar'),
#  Home(price=9900000, monthly_fee=3700, living_area=200.0, number_rooms=6, type='house', address='Fasanvägen 5, Sigtuna'),
#  Home(price=2000000, monthly_fee=3000, living_area=38.0, number_rooms=1, type='apartment', address='Skånegatan 101, Göteborg'),
#  Home(price=6500000, monthly_fee=2400, living_area=150.0, number_rooms=5, type='house', address='Lövnäsvägen 20, Falun'),
#  Home(price=4000000, monthly_fee=5300, living_area=82.0, number_rooms=3, type='apartment', address='Östra Rönneholmsvägen 8, Malmö'),
#  Home(price=3200000, monthly_fee=1900, living_area=105.0, number_rooms=4, type='house', address='Ringvägen 40, Trelleborg'),
#  Home(price=5700000, monthly_fee=5600, living_area=98.0, number_rooms=4, type='apartment', address='Vasagatan 3, Stockholm'),
#  Home(price=11000000, monthly_fee=4000, living_area=230.0, number_rooms=7, type='house', address='Parkvägen 1, Saltsjöbaden'),
#  Home(price=2500000, monthly_fee=3600, living_area=52.0, number_rooms=2, type='apartment', address='Klostergatan 10, Uppsala'),
#  Home(price=4700000, monthly_fee=2000, living_area=118.0, number_rooms=4, type='house', address='Skogsvägen 30, Sundsvall'),
#  Home(price=3400000, monthly_fee=4600, living_area=69.0, number_rooms=2, type='apartment', address='Drottninggatan 15, Norrköping'),
#  Home(price=8500000, monthly_fee=3300, living_area=185.0, number_rooms=6, type='house', address='Aspvägen 12, Lomma'),
#  Home(price=4100000, monthly_fee=5400, living_area=84.0, number_rooms=3, type='apartment', address='Folkungagatan 100, Stockholm'),
#  Home(price=5000000, monthly_fee=2500, living_area=128.0, number_rooms=4, type='house', address='Vattengatan 7, Karlskrona'),
#  Home(price=2300000, monthly_fee=3100, living_area=45.0, number_rooms=2, type='apartment', address='Kaserngatan 6, Luleå'),
#  Home(price=7800000, monthly_fee=3400, living_area=175.0, number_rooms=6, type='house', address='Vårvägen 25, Mölndal'),
#  Home(price=3800000, monthly_fee=5000, living_area=78.0, number_rooms=3, type='apartment', address='Sankt Petri Kyrkogata 11, Lund'),
#  Home(price=12000000, monthly_fee=4200, living_area=240.0, number_rooms=7, type='house', address='Villa Grande 2, Saltsjö-Boo')]

# %%
homes = response.parsed
len(homes)
# Out:
# 50

# %%
homes[0]
# Out:
# Home(price=4200000, monthly_fee=3800, living_area=75.5, number_rooms=3, type='apartment', address='Vasagatan 12A, Stockholm')

# %%
homes[0].price, homes[0].address
# Out:
# (4200000, 'Vasagatan 12A, Stockholm')

# %%
homes[0].__dict__
# Out:
# {'price': 4200000,
#  'monthly_fee': 3800,
#  'living_area': 75.5,
#  'number_rooms': 3,
#  'type': 'apartment',
#  'address': 'Vasagatan 12A, Stockholm'}

# %%
import pandas as pd 

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#      price  monthly_fee  living_area  number_rooms       type  \
# 0  4200000         3800         75.5             3  apartment
# 1  6800000         2200        140.0             5      house
# 2  2850000         4500         62.0             2  apartment
# 3  3100000         1800        110.0             4      house
# 4  5500000         5200         95.0             4  apartment
#
#                           address
# 0        Vasagatan 12A, Stockholm
# 1             Ekallén 5, Göteborg
# 2   Södra Förstadsgatan 33, Malmö
# 3          Björkvägen 15, Uppsala
# 4  Kungsportsavenyen 20, Göteborg

# %%
df.query("price < 5_000_000")
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 0   4200000         3800         75.5             3  apartment
# 2   2850000         4500         62.0             2  apartment
# 3   3100000         1800        110.0             4      house
# 6   2100000         3200         48.0             2  apartment
# 7   4300000         2500        125.0             5      house
# 8   3500000         4800         70.0             3  apartment
# 10  1900000         2900         35.0             1  apartment
# 12  4800000         5800         88.0             3  apartment
# 13  3700000         1500        100.0             4      house
# 14  2600000         4100         55.0             2  apartment
# 16  3900000         5000         80.0             3  apartment
# 18  1750000         2800         30.0             1  apartment
# 20  3300000         4300         68.0             2  apartment
# 21  4900000         2100        115.0             4      house
# 24  2400000         3900         50.0             2  apartment
# 25  4600000         2600        120.0             4      house
# 26  3000000         4700         65.0             2  apartment
# 28  4400000         5100         85.0             3  apartment
# 30  2200000         3400         40.0             1  apartment
# 32  3600000         4900         72.0             3  apartment
# 34  2000000         3000         38.0             1  apartment
# 36  4000000         5300         82.0             3  apartment
# 37  3200000         1900        105.0             4      house
# 40  2500000         3600         52.0             2  apartment
# 41  4700000         2000        118.0             4      house
# 42  3400000         4600         69.0             2  apartment
# 44  4100000         5400         84.0             3  apartment
# 46  2300000         3100         45.0             2  apartment
# 48  3800000         5000         78.0             3  apartment
#
#                            address
# 0         Vasagatan 12A, Stockholm
# 2    Södra Förstadsgatan 33, Malmö
# 3           Björkvägen 15, Uppsala
# 6           Storgatan 7, Linköping
# 7         Solhemsgatan 7, Västerås
# 8    Järnvägsgatan 10, Helsingborg
# 10            Studentvägen 5, Lund
# 12              Hamngatan 1, Malmö
# 13      Hantverkargatan 18, Örebro
# 14     Västra Esplanaden 12, Växjö
# 16        Kungsgatan 42, Stockholm
# 18    Trädgårdsgatan 2B, Jönköping
# 20      Svartbäcksgatan 1, Uppsala
# 21           Kattfotgatan 9, Borås
# 24           Ågatan 17, Eskilstuna
# 25        Blåklintsvägen 14, Gävle
# 26            Stortorget 5, Örebro
# 28        Karlavägen 78, Stockholm
# 30         Klostergatan 21, Skövde
# 32   Fredriksbergsvägen 15, Kalmar
# 34        Skånegatan 101, Göteborg
# 36  Östra Rönneholmsvägen 8, Malmö
# 37        Ringvägen 40, Trelleborg
# 40        Klostergatan 10, Uppsala
# 41        Skogsvägen 30, Sundsvall
# 42   Drottninggatan 15, Norrköping
# 44    Folkungagatan 100, Stockholm
# 46            Kaserngatan 6, Luleå
# 48  Sankt Petri Kyrkogata 11, Lund

# %%
df.query("price < 5_000_000 and type == 'house'")
# Out:
#       price  monthly_fee  living_area  number_rooms   type  \
# 3   3100000         1800        110.0             4  house
# 7   4300000         2500        125.0             5  house
# 13  3700000         1500        100.0             4  house
# 21  4900000         2100        115.0             4  house
# 25  4600000         2600        120.0             4  house
# 37  3200000         1900        105.0             4  house
# 41  4700000         2000        118.0             4  house
#
#                        address
# 3       Björkvägen 15, Uppsala
# 7     Solhemsgatan 7, Västerås
# 13  Hantverkargatan 18, Örebro
# 21       Kattfotgatan 9, Borås
# 25    Blåklintsvägen 14, Gävle
# 37    Ringvägen 40, Trelleborg
# 41    Skogsvägen 30, Sundsvall

# %%
cheap_houses = df.query("price < 5_000_000 and type == 'apartment'")
cheap_houses
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 0   4200000         3800         75.5             3  apartment
# 2   2850000         4500         62.0             2  apartment
# 6   2100000         3200         48.0             2  apartment
# 8   3500000         4800         70.0             3  apartment
# 10  1900000         2900         35.0             1  apartment
# 12  4800000         5800         88.0             3  apartment
# 14  2600000         4100         55.0             2  apartment
# 16  3900000         5000         80.0             3  apartment
# 18  1750000         2800         30.0             1  apartment
# 20  3300000         4300         68.0             2  apartment
# 24  2400000         3900         50.0             2  apartment
# 26  3000000         4700         65.0             2  apartment
# 28  4400000         5100         85.0             3  apartment
# 30  2200000         3400         40.0             1  apartment
# 32  3600000         4900         72.0             3  apartment
# 34  2000000         3000         38.0             1  apartment
# 36  4000000         5300         82.0             3  apartment
# 40  2500000         3600         52.0             2  apartment
# 42  3400000         4600         69.0             2  apartment
# 44  4100000         5400         84.0             3  apartment
# 46  2300000         3100         45.0             2  apartment
# 48  3800000         5000         78.0             3  apartment
#
#                            address
# 0         Vasagatan 12A, Stockholm
# 2    Södra Förstadsgatan 33, Malmö
# 6           Storgatan 7, Linköping
# 8    Järnvägsgatan 10, Helsingborg
# 10            Studentvägen 5, Lund
# 12              Hamngatan 1, Malmö
# 14     Västra Esplanaden 12, Växjö
# 16        Kungsgatan 42, Stockholm
# 18    Trädgårdsgatan 2B, Jönköping
# 20      Svartbäcksgatan 1, Uppsala
# 24           Ågatan 17, Eskilstuna
# 26            Stortorget 5, Örebro
# 28        Karlavägen 78, Stockholm
# 30         Klostergatan 21, Skövde
# 32   Fredriksbergsvägen 15, Kalmar
# 34        Skånegatan 101, Göteborg
# 36  Östra Rönneholmsvägen 8, Malmö
# 40        Klostergatan 10, Uppsala
# 42   Drottninggatan 15, Norrköping
# 44    Folkungagatan 100, Stockholm
# 46            Kaserngatan 6, Luleå
# 48  Sankt Petri Kyrkogata 11, Lund

# %%
cheap_houses.to_csv("cheap_houses.csv", index=False)
